# %%
import json
import pandas as pd
from collections import Counter

# %%
def load_gene_runs(filepath):
    runs = []
    with open(filepath) as f:
        for line in f:
            runs.append(json.loads(line))
    return runs

# %%
df = pd.read_csv('../data/0_data_for_mlp/TCGA-BRCA.star_tpm.csv')

N_TOP = 3000
outer = 0

# %%
runs = load_gene_runs(
        f"../data/clinical_data/brca_clinical/shap_experiment/outer_{outer}/outer_{outer}.jsonl"
    )

# %%
# === zbieramy top geny z każdego folda ===
gene_lists = [run["genes"][:1000] for run in runs]
n_runs = len(gene_lists)

# flatten
all_genes = [g for lst in gene_lists for g in lst]

# === liczymy częstość występowania ===
freq = Counter(all_genes)

# === grupujemy po liczbie foldów, w których gen występuje ===
grouped = {}
for gene, count in freq.items():
    grouped.setdefault(count, []).append(gene)

# %%
len(grouped[5])
# Out:
# 840

# %%
for outer in range(5):

    runs = load_gene_runs(
        f"../data/clinical_data/brca_clinical/shap_experiment/outer_{outer}/outer_{outer}.jsonl"
    )

    # === zbieramy top geny z każdego folda ===
    gene_lists = [run["genes"] for run in runs]
    n_runs = len(gene_lists)

    # flatten
    all_genes = [g for lst in gene_lists for g in lst]

    # === liczymy częstość występowania ===
    freq = Counter(all_genes)

    # === grupujemy po liczbie foldów, w których gen występuje ===
    grouped = {}
    for gene, count in freq.items():
        grouped.setdefault(count, []).append(gene)

    print(grouped)
    selected = []
    used = set()

    # od najbardziej konsensusowych do najmniej
    for k in range(n_runs, 0, -1):
        if k in grouped:
            for gene in grouped[k]:
                if gene not in used:
                    selected.append(gene)
                    used.add(gene)
                if len(selected) >= N_TOP:
                    break
        if len(selected) >= N_TOP:
            break

    print(f"Outer {outer}: selected {len(selected)} genes")

    # # fallback jeśli nie dobijesz do 3000
    # if len(selected) < N_TOP:
    #     remaining = [g for g in freq.keys() if g not in used]
    #     selected.extend(remaining[:N_TOP - len(selected)])

    # # === filtr DF ===
    # columns = [col for col in selected if col in df.columns]
    # columns.insert(0, 'Unnamed: 0')

    # df_selected = df[columns]

    # df_selected.to_csv(
    #     f"../data/0_data_for_mlp_testing/top_shap_3k_training_outer_{outer}.csv",
    #     index=False
    # )
# Out:
# {4: ['TLX1', 'PCP4L1', 'UQCR11', 'TMEM81', 'ELOVL2', 'ERP27', 'EFHC2', 'ARSJ', 'RLN2', 'OSM', 'CTD-2192J16.22', 'MEA1', 'CIPC', 'PDPR', 'FBXL7', 'RAD51B', 'GSDMA', 'RBBP7', 'REXO1', 'CSF3R', 'PCDH20', 'RP11-371E8.4', 'ARMC3', 'AZU1', 'MAP7D2', 'CERK', 'MKRN3', 'RLN1', 'ZSWIM3', 'WDR93', 'KDELR1', 'PNPLA3', 'ASIC1', 'DMPK', 'LRRC56', 'FAM83G', 'ODAD2', 'NPM1', 'FAAP24', 'DMAP1', 'NBPF1', 'CAPSL', 'ERF', 'PMAIP1', 'NBL1', 'RGS1', 'EVL', 'UBD', 'SCRN1', 'STXBP1', 'C10orf67', 'PHACTR2', 'GP6', 'CNGA4', 'C19orf25', 'ABHD5', 'PSMF1', 'NACA', 'ATP5IF1', 'IRX2', 'MAK', 'AC005787.5', 'CDC34', 'MRPS28', 'OFD1', 'NPHP1', 'OXCT2', 'C2orf15', 'TMF1', 'PSD3', 'NDUFS7', 'RP1-137D17.4', 'TMEM161A', 'GCLM', 'MED29', 'SLC25A10', 'SERINC5', 'CDK2', 'C11orf16', 'DET1', 'GTPBP2', 'SH3BP5', 'FAM167B', 'SMARCE1', 'ZRSR2', 'PERM1', 'SCGB1C1', 'SLC19A1', 'RBM11', 'USF2', 'MSI1', 'DTX2', 'FBXO32', 'ATL3', 'SYTL4', 'PRRT3', 'SERPINH1', 'SCGB1D2', 'ARHGAP6', 'AK1', 'ACOT4', 'QRICH1', 'HIC2', 'ZBED9', 'TSPO2', 'UBQLNL', 'FAHD2B', 'MAGED4B', 'CYSLTR1', 'C9orf40', 'GZF1', 'GFI1', 'FHOD1', 'CSTL1', 'GPRASP2', 'ADGRL3', 'CLASRP', 'CA11', 'ZNF774', 'WDR97', 'STX7', 'OGA', 'CASTOR2', 'EP400P1', 'NBPF25P', 'TLCD1', 'RSPH1', 'FAM204A', 'CCDC97', 'TMEM240', 'CDKL3', 'DAGLB', 'KIAA1614', 'AMPD2', 'GNG8', 'GNA11', 'RXRB', 'MAP3K7CL', 'RBKS', 'PER3', 'CLCN7', 'IDO1', 'PRRG4', 'RPL11', 'MTSS1', 'THSD4', 'GPR4', 'CCER2', 'HACD1', 'SLC7A6', 'SMTNL1', 'ID3', 'ZNF776', 'AGMAT', 'PDLIM2', 'GK', 'H2AC4', 'LY6G6C', 'G3BP1', 'WDR38', 'APOBEC3D', 'MBTD1', 'MT-ND6', 'AE000662.92', 'SULT1A3', 'PLLP', 'TMEM211', 'SNAP23', 'FOXN1', 'MICB', 'PPP1R3F', 'RALGAPB', 'ANAPC10', 'SNHG28', 'IQCH', 'ZCCHC17', 'NSMF', 'DRGX', 'TOP2A', 'STOX1', 'ZNF101', 'PLA2G2C', 'ZSCAN21', 'RIPOR1', 'ZNF625', 'ARRDC5', 'MAPKAPK3', 'GCNA', 'GRPR', 'OR2W3', 'PAPPA', 'MORN2', 'ANKRD28', 'MROH8', 'PNPLA1', 'FLNB', 'NDRG1', 'TEKT5', 'HLA-DOB', 'FAM200B', 'UBL4A', 'NQO1', 'JUND', 'BTBD19', 'RPS2', 'ARMC12', 'CLEC3A', 'LBX2', 'UBXN10', 'CD99L2', 'PTPN7', 'IER3', 'CNDP2', 'FARP2', 'PDE6B', 'PCDHB6', 'ZP1', 'BHLHE40', 'GSKIP', 'ERICH3', 'AURKC', 'SAFB2', 'SLC22A17', 'NPAS3', 'SLC22A13', 'THAP8', 'CDK12', 'ACTG1', 'KBTBD11', 'FAXC', 'HLA-DQB2', 'PCP2', 'WFIKKN2', 'SLC41A3', 'LRRN2', 'TBCEL-TECTA', 'KIF12', 'LRRC23', 'NDST2', 'SERHL2', 'ZFYVE16', 'TRIM54', 'TEX48', 'PCGF3', 'HIKESHI', 'G6PC2', 'ADK', 'RAB26', 'POP5', 'RP5-1148A21.4', 'GRIK5', 'RP11-554A11.11', 'CEACAM5', 'SLC20A1', 'SLC45A2', 'PIK3R1', 'TBC1D30', 'ST8SIA6', 'NAP1L1', 'HEY1', 'CTSD', 'CEACAM1', 'CDC6', 'RNF139', 'ENO4', 'SPHK2', 'RP11-867G23.8', 'ADI1', 'DKK2', 'DERL1', 'CALCOCO2', 'SAG', 'SEMA6C', 'FAM81B', 'PLCD4', 'RUNX1', 'SLC27A6', 'MPV17', 'DNAH5', 'RPRD2', 'LANCL1', 'EXOC7', 'PGBD5', 'EOLA2', 'MYOG', 'GMPPB', 'PDCD4', 'SFTPA1', 'ECT2L', 'ENSG00000275493.2', 'NDEL1', 'PSME2', 'PRDX4', 'NTM', 'TRIM45', 'MT3', 'PCGF5', 'CDH19', 'DLG5', 'KIFC3', 'AP2A1', 'RBMS3', 'SLC25A48', 'XKRX', 'SLC7A13', 'SLC29A2', 'EXOC6', 'H2AC20', 'HDAC7', 'RPS6KL1', 'LRRC3', 'GJC2', 'RPS27', 'STAU1', 'ZDHHC7', 'C10orf82', 'PITPNM3', 'LINC02868', 'SYS1-DBNDD2', 'EIF3B', 'SH2D1B', 'RAMP1', 'RTL8C', 'CYB561D1', 'GBP5', 'BTC', 'NR1D2', 'H2BC7', 'CD1A', 'DCPS', 'NIPAL2', 'LGALS7B', 'CDC42', 'UBE2L6', 'RABAC1', 'CD24', 'CPXM2', 'TRIM7', 'CRLF2', 'BAG1', 'SPRY4', 'PTAR1', 'FAM170B', 'FBF1', 'ZNF587B', 'SKOR1', 'DHRSX', 'E2F5', 'CCDC173', 'FANCD2', 'GRWD1', 'PELO', 'PCDHB3', 'ALYREF', 'OSBPL8', 'SULT1C2', 'KCNE2', 'NTNG2', 'MS4A8', 'ISCA2', 'NOS3', 'AQP8', 'TOMM40L', 'RGS3', 'NRN1L', 'SPRR3', 'SLC26A4', 'C15orf62', 'TMEM42', 'IRX1', 'COPG2', 'YOD1', 'RBM15B', 'GDPD5', 'KIR3DL2', 'CNTD1', 'ZNF619', 'MACROH2A1', 'ZNF8-ERVK3-1', 'DHX58', 'AGBL4', 'ZNF92', 'CD52', 'MYL10', 'SURF4', 'RP11-577H5.5', 'CACNA1B', 'GPSM3', 'GPRACR', 'ESAM', 'WFDC13', 'RGL2', 'FAM131A', 'CPLX4', 'SLC1A4', 'BRF2', 'MYH6', 'CTU2', 'ELP6', 'KDM4B', 'TBCEL', 'DNASE1L1', 'ABHD14A', 'USP19', 'CBLN3', 'CIB3', 'PLEKHH3', 'RPS4Y1', 'GHRL', 'MCOLN2', 'PAK6', 'DKK3', 'MRPS33', 'NDUFAF3', 'HDAC2', 'KIAA0319L', 'SELE', ...
# Outer 0: selected 3000 genes
# {5: ['HBA2', 'SFTPA1', 'SH3BP2', 'ERP27', 'SERHL2', 'SFTPC', 'AZU1', 'TUBA3E', 'KCNC4', 'AK7', 'SERPINA3', 'LRG1', 'EPB41L4B', 'SERPINA6', 'ADH7', 'PAQR4', 'CCDC160', 'HTR1D', 'FGL1', 'NBPF1', 'DMC1', 'PCYT2', 'LINC02166', 'LINC01644', 'CCDC74B', 'CNGA4', 'ATP5IF1', 'PHF7', 'POTEJ', 'SLC35G3', 'ARPC4-TTLL3', 'SAMD10', 'PSENEN', 'QRFPR', 'MYOZ1', 'ZNF107', 'C5orf17', 'SLC4A8', 'CLEC3A', 'PRLH', 'ABAT', 'TMEM31', 'C5orf60', 'SIAH2', 'NEK10', 'CYP4F3', 'DUS1L', 'FAM200B', 'GFRA2', 'H2AC19', 'GP6', 'ZSWIM3', 'GPRC5D', 'MCIDAS', 'AMPH', 'TMEM105', 'ZNF433', 'ADPRH', 'MRPS28', 'ICOSLG', 'ROPN1L', 'RP5-1148A21.4', 'ZDHHC15', 'NOS1AP', 'PDLIM5', 'OR51E1', 'CYP4A11', 'CCDC17', 'GALT', 'RLN2', 'SH3BGR', 'ASCL3', 'LUC7L3', 'ANKRD49', 'ERICH3', 'ZMYND10', 'KCNF1', 'MORN1', 'RGPD6', 'PLEKHH1', 'DUSP15', 'COG8', 'EME2', 'POFUT2', 'CEBPE', 'PDCD4', 'LCN12', 'CAMK2D', 'SFTPB', 'OR2A7', 'STC2', 'TYRP1', 'MYCBPAP', 'RIPOR1', 'TMEM81', 'CYP4F22', 'RPGRIP1', 'GRAP', 'PGLYRP2', 'OR5K2', 'BTBD16', 'EMX1', 'SPPL2C', 'IZUMO4', 'HUS1B', 'CSF3R', 'SERPINA4', 'CSTL1', 'PYDC1', 'ACAT1', 'MAP2K6', 'GIGYF1', 'CABCOCO1', 'TMEM242', 'NFE2', 'SPINK4', 'GNMT', 'ESRRG', 'SCRN1', 'C16orf71', 'STX7', 'KIR2DL4', 'ZNF101', 'FLCN', 'KCNJ11', 'SLC25A41', 'CRYM', 'RAB3IP', 'TRIM45', 'MAGEB17', 'GCNA', 'PLAAT4', 'CST9', 'MCAM', 'SUSD3', 'ANKRD28', 'SH3D21', 'CD99L2', 'CCDC175', 'PNMA6B', 'NPAS3', 'FAM72C', 'ZPBP', 'ALG9', 'DPY19L2', 'PDE6H', 'TMTC2', 'ALS2CL', 'ATRIP', 'BTG2', 'OR7D2', 'RP11-577H5.5', 'C1orf167', 'RNF26', 'CHPT1', 'S100A16', 'NLRX1', 'C1orf226', 'WFDC10B', 'PAXIP1-AS2', 'ZNF514', 'SNHG28', 'ZNF208', 'NIPAL2', 'CYP4F2', 'UQCR11', 'SMARCA2', 'PHLDA3', 'LARS2', 'PGC', 'KIAA1614', 'ZNF644', 'SEPTIN12', 'TEX48', 'PCLO', 'ROBO3', 'CLIC6', 'ZNF648', 'FEZ1', 'GREB1L', 'C17orf77', 'TJP3', 'ATP6V1B1', 'RGPD2', 'EI24', 'MBOAT1', 'AMDHD1', 'DOK4', 'DERL1', 'CLEC6A', 'H2BC4', 'ADD3-AS1', 'SLC23A1', 'BST2', 'SOCS3', 'FITM1', 'SMCHD1', 'HNRNPCL1', 'CDHR4', 'GRPR', 'PGF', 'RP11-770J1.5', 'IL1RL2', 'IHH', 'SREBF1', 'RSAD1', 'RNASE1', 'TTC21A', 'SLC16A2', 'ISLR2', 'TAC4', 'ENSG00000275493.2', 'TBCB', 'PARP9', 'RBM7', 'CRYZ', 'SERPINA1', 'ZCCHC17', 'TTC36', 'FAM81B', 'TEX54', 'FAAP24', 'CLN8', 'FCRL4', 'CCNO', 'GSTK1', 'KRT15', 'NIBAN1', 'MRPS24', 'STOX1', 'TRIM73', 'ARAP3', 'MAPT', 'LPCAT4', 'C11orf53', 'ATF5', 'JRKL', 'GBP4', 'TMEM232', 'PSKH1', 'POTEI', 'SEMA3B', 'TBCEL-TECTA', 'CEP57', 'FAM83E', 'CHAD', 'AC009403.2', 'TBC1D3E', 'IQGAP2', 'SDHD', 'HLA-G', 'IDO1', 'PCGF5', 'GDPD5', 'ECHDC3', 'CPEB1', 'PRXL2B', 'GPR62', 'SPEF1', 'TUBA3D', 'SFMBT1', 'LINC01948', 'RBM4', 'NCAM2', 'APOA1', 'NOL4L', 'FAM131A', 'RIDA', 'STRC', 'GLG1', 'ANKRD46', 'CTD-2192J16.22', 'PSME2', 'CDH19', 'AMFR', 'ELOC', 'EMC6', 'ECI1', 'FOXJ1', 'PARP3', 'ITPR2', 'DTHD1', 'PEDS1', 'NPIPB9', 'PPP4R4', 'OIT3', 'C6orf226', 'KCNE2', 'ZNF26', 'MICB', 'IFITM5', 'RIBC1', 'DAXX', 'DRC3', 'DLX2', 'ADK', 'CHRM1', 'FCRL5', 'HIC2', 'SYT5', 'ASB1', 'GPATCH1', 'ITGA3', 'SLC41A3', 'ABHD11', 'IFI6', 'ASPSCR1', 'HIKESHI', 'FGD3', 'BTBD6', 'ARMC12', 'CCDC9B', 'RASGRP1', 'FKBP1C', 'STX8', 'PCDHB3', 'EGFLAM', 'LCN1', 'IL21', 'IRX2', 'HTRA4', 'ZNF92', 'KRT37', 'LZTFL1', 'PCDHGA10', 'GSTZ1', 'RAP1GAP2', 'SLC39A8', 'MCOLN2', 'GFRA4', 'ATPSCKMT', 'IGFN1', 'CYP4F11', 'YBEY', 'SFXN2', 'HLA-DQB2', 'KCNE3', 'RAPGEFL1', 'MAP7D2', 'GRIK5', 'CASP9', 'SNTN', 'ARHGAP4', 'ZNF202', 'FAM171A2', 'TOM1L1', 'VCPIP1', 'FAM71E2', 'IQCC', 'CTD-3105H18.16', 'PCDH17', 'ACADM', 'IL4', 'RP11-434N15.2', 'LINC01124', 'C20orf85', 'VRK2', 'GPR151', 'CRYGS', 'ATP7B', 'AQP10', 'CCL25', 'EPHX4', 'BRICD5', 'CPNE2', 'ID3', 'KCNK1', 'SCAMP4', 'NUDT4P2', 'EVC2', 'DDAH1', 'ACSL1', 'GBP2', 'HSPA6', 'ZNF44', 'IGFL4', 'FBXO27', 'FCRLB', 'CCL19', 'PPP2R2B', 'CD79A', 'STAT1', 'SPINT3', 'HEPACAM2', 'TEX38', 'ARHGEF26', 'CST1', 'WFDC13', 'DCAF16', 'PRKAR1B', 'SH2D6', 'LSM6', 'RXFP4', 'CCDC73', 'CCDC54', 'SMIM6', 'CATSPERG', 'PIK3R3', 'RP11-1105G2.3', 'FXYD3', 'DSG2', 'C10orf67', 'PLPP2', 'CENATAC', 'TLCD4', 'RHO', 'TEKT5', 'CISH', 'PCMT1', 'PIM2', 'CEBPA', 'FAM10 ...
# Outer 1: selected 3000 genes
# {5: ['TDGF1', 'SERPINA6', 'ASCL3', 'RP11-279O9.4', 'EMX1', 'KCNC4', 'HIF3A', 'POTEJ', 'EPB41L4B', 'KLRB1', 'AGPAT4', 'TAC4', 'SIAH2', 'DNAJC19', 'ROBO3', 'PSENEN', 'KRTAP3-2', 'GP6', 'LEF1', 'RFX8', 'SFTPA1', 'SFTPB', 'UBBP4', 'PIK3C2G', 'FABP7', 'GREB1L', 'GLIPR1L1', 'SEC16B', 'C5orf17', 'SP5', 'TMEM31', 'ADGRF3', 'NEK10', 'LINC02166', 'TBCEL-TECTA', 'ABO', 'BTBD19', 'RP11-1396O13.13', 'DLX1', 'PCDH17', 'MIF-AS1', 'CELA2B', 'ADH7', 'PRSS2', 'SLC1A4', 'PCDHB3', 'ADD3-AS1', 'HLA-DQB2', 'ADAMTS8', 'CHAD', 'GOLGA8G', 'U2AF1L5', 'AVEN', 'GTSF1L', 'TLR10', 'GSTT2B', 'KCNF1', 'CLN8', 'NOS1AP', 'L1CAM', 'DRC3', 'OMP', 'SH3BGR', 'ARPC4-TTLL3', 'HUS1B', 'LINC01124', 'C5orf66', 'NTNG1', 'COX19', 'FUT6', 'BCL2A1', 'PLCZ1', 'ATP6V1B1', 'MTRNR2L9', 'ACY1', 'LINC01644', 'ETNPPL', 'C5orf60', 'SREBF1', 'CPEB1', 'IL36A', 'SLC23A1', 'ABAT', 'RHOH', 'NBPF6', 'SLFNL1', 'ECRG4', 'CLRN1', 'WDR91', 'ACOT1', 'YKT6', 'AE000662.92', 'TBC1D3D', 'SNHG28', 'CCDC116', 'MAK', 'KCNE3', 'CLEC6A', 'KLF9', 'CCDC17', 'HOXB1', 'TUBB8', 'AC011997.1', 'POTED', 'RP11-650K20.3', 'PSD3', 'INSYN2A', 'SPPL2C', 'CEND1', 'CD52', 'CACNG3', 'HIC2', 'PNPLA3', 'H2AC4', 'SNORC', 'CIB3', 'NMRK1', 'CD3E', 'POTEI', 'EFCAB12', 'TMEM242', 'SLC10A6', 'FGD3', 'WFDC10B', 'MUC15', 'CD1E', 'PARVA', 'C20orf144', 'FOXJ1', 'IFNLR1', 'FEZ1', 'ERICH3', 'LMBR1L', 'ESRRG', 'RP11-577H5.5', 'KIF5C', 'CCR9', 'GP1BA', 'OR7D2', 'RASGRP1', 'IFRD1', 'TMEM213', 'C1orf167', 'ZNF101', 'C1orf226', 'IL21', 'SLC25A35', 'CDH18', 'MICB', 'PHF7', 'AP4B1', 'C10orf67', 'RBM7', 'RGS3', 'KRT37', 'GRIK5', 'MROH7-TTC4', 'MCAM', 'FAM72C', 'HLA-G', 'C6orf226', 'RHO', 'ANXA3', 'RP5-864K19.6', 'PSD2', 'SFTPC', 'CCL19', 'SPOCK3', 'SFXN2', 'GPR151', 'AC108938.5', 'FCRL3', 'GPR62', 'PPP4R4', 'SERPINA1', 'HMG20B', 'GPA33', 'HACL1', 'MCOLN2', 'TRIM73', 'SUSD3', 'REELD1', 'TAS2R9', 'TFCP2L1', 'PSMF1', 'PEDS1', 'RP11-1105G2.3', 'IL4', 'TEX54', 'NPAS3', 'TFF2', 'CCDC185', 'FAM183BP', 'CCDC74B', 'GSTM1', 'TTC36', 'GPR27', 'KIR2DL4', 'LIMD2', 'IPO4', 'TYRP1', 'LAMP3', 'FEZF2', 'SCAND1', 'NXNL2', 'CTD-3105H18.16', 'A3GALT2', 'ZFAND2A', 'MAP6D1', 'CCDC175', 'INTS6L', 'SLC25A41', 'RP5-876B10.7', 'CDCP2', 'SYT5', 'FBXO36', 'LINC01948', 'VDR', 'TMEM221', 'PGF', 'CATSPERG', 'PYDC1', 'DLX6', 'REL', 'NRXN1', 'ACSL1', 'CFAP99', 'JPH2', 'PLA2G2D', 'SNX22', 'CYB561D1', 'TMEM156', 'ATP6V0A4', 'MAP2K6', 'PIP5K1C', 'LARS2', 'CDH22', 'TPRG1', 'SNTN', 'MTCL1', 'PARP9', 'GSTA4', 'BTBD16', 'KCTD3', 'CCDC89', 'ANKRD2', 'MYCBPAP', 'ARMC12', 'ATP7B', 'LCN1', 'POTEE', 'NLRP8', 'MCIDAS', 'SLC1A1', 'TRARG1', 'NPIPB15', 'MIXL1', 'CTC-260F20.3', 'FAM135B', 'KCNK3', 'MORN1', 'TEKT5', 'MRO', 'RP13-122B23.13', 'HDAC7', 'TUBA3D', 'MALRD1', 'S100A16', 'VSIG4', 'COBLL1', 'TMEM65', 'CHPT1', 'TMIGD2', 'EDDM3B', 'URAD', 'OR5K2', 'EIF2S3B', 'SCRN1', 'YBEY', 'C15orf32', 'COBL', 'PTGDR2', 'XXbac-BPG300A18.14', 'ZNF619', 'TUBA3E', 'ZNF552', 'DRC7', 'TECTA', 'MCTS1', 'ENPP6', 'GPR25', 'SVOPL', 'C1QTNF7', 'XRCC4', 'FABP2', 'TCTE1', 'TIFAB', 'PTPRT', 'COX6C', 'CDHR4', 'TMC3', 'SSTR1', 'PRDX4', 'RPGRIP1', 'CES3', 'VSIG1', 'STAT1', 'BATF2', 'XCR1', 'SFMBT1', 'ADH1A', 'DDAH1', 'NPIPB11', 'H2AC19', 'SHOC1', 'RPL36', 'ADGRE3', 'HAO2', 'CRAT', 'TP73', 'PLAAT2', 'ANKRD53', 'PTPRR', 'DNAH17-AS1', 'CAMK2N2', 'PTPN1', 'CYP24A1', 'IGFLR1', 'TCERG1L', 'H2BC4', 'CLIC6', 'LUC7L3', 'STEEP1', 'CST7', 'PLAAT4', 'TSFM', 'CCDC9B', 'TBC1D3E', 'FOXQ1', 'FLT3', 'HIKESHI', 'EXOSC8', 'RP11-310N16.1', 'CYRIA', 'ELOC', 'FAM181B', 'DTHD1', 'GRB10', 'RXFP4', 'TJP3', 'ECEL1', 'ZNF26', 'IL24', 'IGFL4', 'CCL22', 'KCNA10', 'FCRL5', 'PCDHA8', 'ARHGAP22', 'ANKRD28', 'KRTAP3-3', 'HTR1D', 'PTPN7', 'KCNJ10', 'GJA3', 'AC023590.1', 'DMPK', 'C19orf84', 'EXOC3-AS1', 'FAM25G', 'FAM117A', 'GUCY2C', 'C17orf77', 'MYBPC1', 'XCL1', 'NLGN1', 'CEBPE', 'MYL10', 'ZNF589', 'CD8B2', 'LRRC74A', 'STMND1', 'CCDC144A', 'GPATCH11', 'GRXCR2', 'REXO2', 'C3orf22', 'CALCOCO2', 'RP11-3B7.1', 'FCRL4', 'AL928654.7', 'TPMT', 'ZC2HC1A', 'RAP1GAP2', 'CYP4F3', 'ACSF2', 'RPS24', 'CCNP', 'SEMA3B', 'CPD', 'RP11-554A11.11', 'STEAP4', 'LRGUK' ...
# Outer 2: selected 3000 genes
# {5: ['TDGF1', 'TMEM31', 'SFTPC', 'TMEM242', 'ETNPPL', 'SERPINA6', 'ATP1A4', 'SIAH2', 'AK7', 'SFTPA1', 'CTD-3105H18.16', 'FABP7', 'VSIG10L2', 'TYRP1', 'KCNE1B', 'NLRP2', 'CASQ1', 'CCDC17', 'CCDC74B', 'SERHL2', 'PCP4L1', 'LHFPL1', 'TTC34', 'ZDHHC15', 'EPB41L4B', 'ADH7', 'NBPF1', 'NOS1AP', 'TMEM81', 'SFTPB', 'LRG1', 'PSENEN', 'ROPN1L', 'RLN2', 'OR51E1', 'CYP4F11', 'GREB1L', 'PPIAL4D', 'FUT6', 'ARPC4-TTLL3', 'CEBPE', 'ELOVL2', 'MAP2K6', 'PLEKHH1', 'HLA-DQB2', 'CYP4F3', 'RP11-986E7.7', 'KCNF1', 'C5orf60', 'CFAP77', 'ABAT', 'ZSCAN1', 'C1orf226', 'PSG4', 'CYP4F2', 'SPPL2C', 'WDR93', 'SLC23A1', 'C5orf17', 'SREBF1', 'LINC01644', 'TUBA3E', 'SLC1A1', 'TFPI2', 'CLEC6A', 'CASP12', 'SERPINA1', 'CLN8', 'POTEI', 'TCF21', 'NFIA', 'BFSP1', 'ADAMTS8', 'CYP4F22', 'LBX2', 'GSTT4', 'KLHDC7B', 'CPEB1', 'NEK10', 'CRYM', 'TMC3', 'RBM4', 'FHL5', 'HOXB1', 'TAC4', 'KLRC1', 'FOXN1', 'TBCEL-TECTA', 'CDHR4', 'GP6', 'ECRG4', 'FEZ1', 'FYB2', 'RP11-1105G2.3', 'POTEJ', 'TRPM2', 'EME2', 'FAM71A', 'PAQR4', 'GTF2H2', 'CLIC6', 'AZU1', 'ATP6V1B1', 'CST4', 'BTBD16', 'NBPF6', 'LCN12', 'RNF39', 'FGL1', 'MTRF1L', 'C6orf99', 'LINC02651', 'MTSS1', 'SCGB3A2', 'TMEM232', 'WFDC10B', 'ZNF26', 'CCDC160', 'SEPTIN12', 'MIF-AS1', 'STRC', 'PCDHB2', 'CD99L2', 'SVOPL', 'HACL1', 'PGC', 'KIR2DL4', 'PTCHD4', 'GRAP', 'RAPGEFL1', 'OR7D2', 'HES5', 'PGLYRP2', 'RP11-577H5.5', 'BDNF', 'ESRRG', 'SUSD3', 'NXNL2', 'NPPA', 'CRYGS', 'PYDC1', 'CSTL1', 'PRLH', 'FOXJ1', 'CATSPERG', 'ERP27', 'PHF7', 'BRF2', 'MORN3', 'RGPD6', 'RPGRIP1', 'DAPL1', 'ZDHHC14', 'SH3BP5', 'STOX1', 'ASCL3', 'MRO', 'C19orf25', 'SYT1', 'C16orf71', 'BCL2A1', 'CABCOCO1', 'MCOLN2', 'KCNJ11', 'CLEC3A', 'KCNC4', 'ZMYND10', 'BST2', 'IL21', 'KCTD3', 'PLEKHG4', 'TUBA3D', 'CH507-9B2.5', 'ABO', 'ACSF2', 'SH3BGR', 'ENPP6', 'TRIM72', 'ACOT1', 'ERICH3', 'SNX3', 'PNKD', 'CLCNKB', 'UGT2B15', 'CCDC57', 'TECTA', 'TEKT4', 'TJP3', 'FAM170B', 'SPINK4', 'FITM1', 'PTGER3', 'PCMT1', 'IGFALS', 'ANKRD28', 'STAC2', 'SLC35G2', 'APOA1', 'SEC16B', 'SPOCK3', 'ZNF433', 'SEC14L2', 'AC017104.2', 'PPP4R4', 'GSTM1', 'CDK5RAP3', 'RP11-279O9.4', 'FAHD2B', 'ENOSF1', 'ZNF587B', 'C1orf53', 'FBXO27', 'SLC1A4', 'FCRLB', 'DMC1', 'TRIM45', 'IL4', 'HIKESHI', 'GLDC', 'GCNA', 'SERPINA4', 'C20orf85', 'STEAP4', 'CACNB3', 'CABP1', 'CAMK2D', 'ACTR3C', 'CCDC175', 'MRPS28', 'H2AC19', 'SNTN', 'GPR62', 'ADORA1', 'CCSER1', 'LINC02166', 'GLDN', 'MTNR1A', 'SOCS3', 'SNTB1', 'LRRC74A', 'C3orf52', 'HUS1B', 'LRFN1', 'SEMA3B', 'COL5A3', 'RGPD2', 'PGF', 'SERPINA5', 'NOL4L', 'ZIK1', 'GPATCH11', 'VSIG1', 'STC2', 'CBLN2', 'LINC01948', 'OBP2A', 'PLPP7', 'IGFL4', 'EMC6', 'PLAAT4', 'LINC01124', 'HUNK', 'RGS4', 'DTHD1', 'RWDD1', 'ZSCAN5A', 'HTR1D', 'ATP7B', 'CYTL1', 'RGS3', 'PDE6B', 'WNT11', 'CHPT1', 'FAM27C', 'PNMA2', 'SFTPA2', 'GRK5', 'LRGUK', 'SCGB3A1', 'MRPS24', 'DEXI', 'RP11-3B7.1', 'FREM2', 'NPAS3', 'STEEP1', 'RP11-762I7.5', 'TXNDC11', 'ZSCAN23', 'ADPRH', 'CAMK2A', 'UQCR11', 'PSME2', 'TAPBPL', 'PDZK1', 'NETO2', 'RXRB', 'ARMC12', 'ZNF875', 'C15orf48', 'CTD-2192J16.22', 'RIBC1', 'DKK2', 'LEF1', 'RP11-650K20.3', 'PLPP2', 'S100A6', 'SLC16A11', 'RP11-244H3.5', 'PCYT2', 'CYP2J2', 'EIF4EBP1', 'CCDC9B', 'S100A16', 'CDC34', 'ACSL1', 'MRPL18', 'DUOX1', 'EFCAB1', 'RP5-876B10.7', 'SNHG28', 'EIF2S3B', 'NFE2', 'TBC1D3E', 'DRC3', 'RP11-126H7.4', 'TCN1', 'H2BC4', 'LRRC8B', 'MYCBPAP', 'GSKIP', 'GJA3', 'IBSP', 'RAP1GAP2', 'RSAD1', 'SCUBE2', 'DDX19A', 'NCAM2', 'MROH7-TTC4', 'EMP1', 'RP11-434N15.2', 'PCDHB3', 'DMPK', 'MPC2', 'SMCO4', 'C1orf167', 'CD207', 'CSPG5', 'HAUS5', 'SLC7A6', 'C17orf77', 'TBPL1', 'WLS', 'SYS1-DBNDD2', 'NBPF25P', 'COG8', 'RFX8', 'REELD1', 'H2AC4', 'WFDC13', 'SERPINA3', 'PIK3R3', 'KRT37', 'KDM4B', 'FGD3', 'NLGN1', 'CES2', 'AMPH', 'CISH', 'ZNF44', 'CHRNA9', 'TPRG1', 'IL36A', 'TMPRSS7', 'SLC4A8', 'DDAH1', 'PKIA', 'MAPT', 'CHAD', 'MRTFA', 'TEX48', 'CES3', 'OR5K2', 'CDH18', 'FBXO36', 'YKT6', 'FOXE1', 'ECI1', 'TCTE1', 'RP11-770J1.5', 'SERPINA10', 'PPL', 'ZFAND2A', 'LRP1B', 'LGI1', 'UGT2B11', 'HABP2', 'KRT32', 'NUDT16L1', 'LRRC71', 'S1PR3', 'LINC01555', 'BTBD19', 'SLC25A41', 'SLC41A3', 'RFPL3S', ...
# Outer 3: selected 3000 genes
# {5: ['AK7', 'CYP4F3', 'TMEM31', 'RP11-279O9.4', 'MGAM', 'SFTPA1', 'TUBA3E', 'ODAD2', 'NAPSA', 'TNNI3', 'ELOVL2', 'PKIA', 'KLRC1', 'PLA2G3', 'FOXJ1', 'ROPN1L', 'HTR1D', 'NBPF1', 'FGL1', 'HACL1', 'CYP4F2', 'HLA-G', 'PGLYRP2', 'RLN2', 'RIBC1', 'TMEM242', 'H1-2', 'SNHG28', 'CCDC74B', 'SLC25A41', 'CST9L', 'GLDC', 'C5orf17', 'CYP4F22', 'SUSD3', 'ANKRD28', 'NBPF25P', 'GP6', 'PLGRKT', 'WDR93', 'APOA1', 'KCNC4', 'PCDHB3', 'NRCAM', 'CCDC17', 'SYNPO2L', 'ABAT', 'H2AC19', 'AKAP14', 'SPPL2C', 'CFAP46', 'SYCE2', 'ADH7', 'C1orf167', 'C16orf71', 'XXbac-BPG300A18.14', 'DOK7', 'ADORA3', 'RAPGEFL1', 'NFE2', 'FOXB2', 'ARPC4-TTLL3', 'BFSP1', 'KIR2DL4', 'C12orf75', 'TRMT10B', 'SLC12A3', 'OR7D2', 'KRT32', 'ZNF101', 'CYP4F11', 'CLEC6A', 'IGFL4', 'PLA2G2C', 'ZNF44', 'ACY1', 'CFAP77', 'CHIT1', 'SFTPB', 'C10orf67', 'CDHR4', 'MED12L', 'SFTPC', 'TAF1L', 'PSKH1', 'ASCL3', 'AZU1', 'SLC35G1', 'WFDC10B', 'CSTL1', 'CCDC9B', 'TUBA3D', 'KCNF1', 'SYT1', 'TMEM232', 'ZMYND10', 'WFDC10A', 'CABCOCO1', 'IZUMO4', 'H3C13', 'GREB1L', 'SERPINA6', 'PLA2G10', 'CDC42EP2', 'RP5-1148A21.4', 'PYDC1', 'CEND1', 'C15orf48', 'GLRA3', 'PLEKHG4', 'IFNE', 'SNX3', 'RGPD6', 'GJA3', 'CD24', 'TMC3', 'CPEB1', 'RWDD1', 'FLCN', 'H2AC4', 'TEX54', 'ERICH3', 'MRPS24', 'ADAMTS8', 'CATSPERG', 'POTEJ', 'FBLL1', 'RAB3IP', 'GPC6', 'IGFLR1', 'PDPR', 'C17orf99', 'PMAIP1', 'RIOX1', 'PTGER3', 'CCNO', 'H2BC4', 'NANOS1', 'IL24', 'KLHDC7B', 'TRPM2', 'KCNJ11', 'TBC1D3E', 'HEBP2', 'CLEC3A', 'SERPINA4', 'BCL2A1', 'MCHR1', 'NOL4L', 'SLC1A1', 'IFNL3', 'TYRP1', 'RPGRIP1', 'SRI', 'MAP1A', 'H2BC7', 'OR5K2', 'FAM156B', 'PNKD', 'ENC1', 'TBC1D30', 'CST9', 'SYNGR3', 'H2BC17', 'RP11-577H5.5', 'ACSM1', 'LRG1', 'SLC9A5', 'H2BC21', 'C6orf99', 'CMTM6', 'KCNE3', 'IL21', 'ALG3', 'RP11-111K18.1', 'ARMC12', 'ITGA3', 'PSMB1', 'STC2', 'HDAC2', 'ZFAND2A', 'TMEM221', 'KRT37', 'HLA-DOB', 'KIAA1614', 'STOX1', 'TCP1', 'MRO', 'TSFM', 'SPAG8', 'PKHD1', 'DAPL1', 'LHFPL1', 'MEIOC', 'SHD', 'PNMA2', 'TCERG1L', 'NAB2', 'SERPINA3', 'MCUB', 'ANKRD18A', 'RHOH', 'DCAF10', 'NT5DC4', 'ELOC', 'ZNF875', 'TLCD4', 'FAR2', 'H2AC18', 'FAAP24', 'CDK19', 'C2CD2', 'BTBD19', 'PHKG2', 'LMNTD2', 'PRSS2', 'PHF7', 'ZNF26', 'PRRG3', 'HIKESHI', 'BTNL9', 'MICB', 'HNRNPCL1', 'MCOLN2', 'VSIG1', 'SLC23A1', 'GPR62', 'CASP12', 'ANKRD2', 'CHPT1', 'EXOSC3', 'ANGPTL2', 'ADGRG6', 'SIAH2', 'EIF2S3B', 'CCNA1', 'STRC', 'CAMP', 'ARL14EP', 'IL4', 'TPSG1', 'GPR27', 'PLCH1', 'CRYGS', 'GTF2H2', 'CHAD', 'GBP6', 'PIK3C2G', 'HS3ST3A1', 'PGC', 'PCMT1', 'ISLR2', 'SNTN', 'ZNF248', 'NXNL2', 'CDH17', 'ABO', 'WDR62', 'PPP4R4', 'BTBD16', 'TMEM81', 'QARS1', 'NRN1L', 'MYCBPAP', 'TOGARAM2', 'ATP7B', 'AMPH', 'SH3BGR', 'OR2B6', 'IGFBP5', 'AMZ1', 'MRPS28', 'LINC01555', 'ADH4', 'RP11-434N15.2', 'TEX48', 'LINC01644', 'TOM1L1', 'ALX1', 'GCNA', 'SEMA3B', 'H2AC13', 'STEEP1', 'RSPH9', 'RAMP1', 'IRX2', 'MSI1', 'C22orf15', 'PCLO', 'AE000662.92', 'SLC25A48', 'AQP8', 'RAP1GAP2', 'RPEL1', 'DNMT1', 'FXYD3', 'RGS4', 'KCNE1B', 'EDDM3B', 'CCDC177', 'MAGEB17', 'UPK3A', 'HNRNPA3', 'KRT13', 'ADORA1', 'DMPK', 'CAMK2D', 'ZNF589', 'MCTS1', 'SIN3A', 'RPF1', 'RNF39', 'TRPA1', 'DYNLT2', 'TFPI2', 'EIF3E', 'ACSF2', 'ZBED6CL', 'COQ3', 'OBP2A', 'SPEGNB', 'IL37', 'HUS1B', 'CST4', 'LRGUK', 'TMEM60', 'COG4', 'TMIGD2', 'ROBO2', 'SERPINA1', 'ATRIP', 'IGF1R', 'GTSF1L', 'DGAT1', 'SLC16A2', 'CRACD', 'C5orf60', 'QRSL1', 'ARAP2', 'WLS', 'GOLGA8G', 'PER3', 'RIPK3', 'RSAD1', 'NPPA', 'POTEI', 'HSPA2', 'CTD-3105H18.16', 'SVOPL', 'FAM171A2', 'TMPRSS13', 'ERMARD', 'ATP6V1B1', 'TRIM72', 'LRRC74B', 'GPR37', 'OVCH1-AS1', 'IL20', 'TMEM98', 'LARS2', 'IHH', 'RP11-650K20.3', 'C1orf226', 'FAM180A', 'RPF2', 'WFDC13', 'ARAP3', 'CLDN14', 'H1-6', 'AS3MT', 'BAMBI', 'NPIPB9', 'SCN8A', 'TTLL4', 'STEAP4', 'LUC7L3', 'PWWP3A', 'RGS3', 'STARD5', 'HIC2', 'RSPO3', 'S1PR3', 'BATF2', 'FOXN1', 'ZC2HC1C', 'SUGCT', 'ACBD5', 'PRKAA2', 'ZSWIM3', 'SPATA31A7', 'TSPAN12', 'C9orf135', 'EPS15L1', 'CNDP1', 'FIGN', 'ALKBH1', 'NQO2', 'FGF8', 'PCDHGB2', 'HAPLN4', 'C7orf57', 'NOS1AP', 'C3orf70', 'RAB4B', 'LDLR', 'FCRLB', 'CCDC175', 'TAPBPL', 'CCNB3', 'TUBE1', 'NME2', 'SMTNL1' ...
# Outer 4: selected 3000 genes
