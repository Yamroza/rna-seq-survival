# %%
import json
from pathlib import Path
import pandas as pd

# %%
results_dir = Path("/scratch/2370352/my-research/repo/src/results/dss_survival_brca/MLP")  # <- zmień jeśli trzeba

# %%
rows = []

for json_file in results_dir.glob("*.json"):
    if json_file.name == "args.json":
        continue
    
    with open(json_file) as f:
        data = json.load(f)

    summary = data["Summary"]

    row = {
        "experiment": json_file.stem,  # nazwa pliku bez .json
        "loss_avg": summary["loss"]["avg"],
        "loss_std": summary["loss"]["std"],
        "c_index_avg": summary["c_index"]["avg"],
        "c_index_std": summary["c_index"]["std"],
        "c_index_ipcw_avg": summary["c_index_ipcw"]["avg"],
        "c_index_ipcw_std": summary["c_index_ipcw"]["std"],
    }

    rows.append(row)

df = pd.DataFrame(rows)
df
# Out:
#                                            experiment  loss_avg  loss_std  \
# 0   Final_results_scgpt_adata_TCGA-BRCA.star_count...  2.933092  0.800330
# 1   Final_results_scgpt_adata_TCGA-BRCA.star_count...  2.981194  0.844640
# 2   Final_results_scgpt_adata_TCGA-BRCA.star_count...  2.975317  0.792908
# 3   Final_results_scgpt_adata_TCGA-BRCA.star_count...  3.060090  0.856143
# 4   Final_results_scgpt_adata_TCGA-BRCA.star_count...  2.994896  0.821577
# 5   Final_results_scgpt_adata_TCGA-BRCA.star_count...  3.022407  0.753483
# 6   Final_results_scgpt_adata_TCGA-BRCA.star_tpm_p...  3.026796  0.838123
# 7   Final_results_scgpt_adata_TCGA-BRCA.star_tpm_p...  3.111888  0.879433
# 8   Final_results_scgpt_adata_TCGA-BRCA.star_tpm_p...  3.019352  0.807336
# 9   Final_results_scgpt_adata_TCGA-BRCA.star_tpm_w...  3.150801  0.873402
# 10  Final_results_scgpt_adata_TCGA-BRCA.star_tpm_w...  3.059583  0.823216
# 11  Final_results_scgpt_adata_TCGA-BRCA.star_tpm_w...  3.016377  0.737952
# 12            Final_results_TCGA-BRCA.star_counts.csv  3.242149  0.963158
# 13               Final_results_TCGA-BRCA.star_tpm.csv  3.404437  1.393548
#
#     c_index_avg  c_index_std  c_index_ipcw_avg  c_index_ipcw_std
# 0      0.556492     0.097667          0.492599          0.043730
# 1      0.548911     0.143610          0.472534          0.069354
# 2      0.516968     0.121031          0.467834          0.054137
# 3      0.463387     0.036280          0.465009          0.067396
# 4      0.541841     0.058519          0.453370          0.084366
# 5      0.448122     0.058159          0.387292          0.083121
# 6      0.544456     0.098905          0.535955          0.073635
# 7      0.502053     0.162862          0.442128          0.079141
# 8      0.538424     0.149986          0.491721          0.115015
# 9      0.549719     0.095645          0.487984          0.127087
# 10     0.487230     0.054791          0.381277          0.073231
# 11     0.492937     0.024210          0.435888          0.039922
# 12     0.650488     0.060661          0.587428          0.063573
# 13     0.686913     0.070343          0.489733          0.129440

# %%
df = df.sort_values(by=["c_index_avg"], ascending=False)

# %%
df.to_csv('../data/results_gathered.csv')
